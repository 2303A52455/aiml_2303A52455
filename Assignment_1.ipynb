# %% [markdown]
# Part 1 – Implement Basic Data Structures using Numpy, Pandas
# 1. Lists
# 2. Arrays
# 3. Identify their type using type()
# 4. Perform mathematical operations on these datasets created - multiplication, division,
# poweroff
# 5. Combine text with Numpy fuction to generate a textual output - ”Addition of Two:
# array1 +array 2
# 6. Implement np.sin(), log(), log2(), np.exp())

# %%
import numpy as np
L1 = [5,6,7,8,9]
a1 = np.array(L1)
print(a1)
# Out:
# [5 6 7 8 9]

# %%
type(L1)
# Out:
# list

# %%
type(a1)
# Out:
# numpy.ndarray

# %%
a2 = np.array([1,2,3,4,5])
l2 = [1,2,3,4,5]

# %%
print("Multiplication of a1 and a2",a1*a2)
print("Division of a2 by a1", a2/a1)
print("a2 raised to the power of a1", a2**a1)
# Out:
# Multiplication of a1 and a2 [ 5 12 21 32 45]
# Division of a2 by a1 [0.2        0.33333333 0.42857143 0.5        0.55555556]
# a2 raised to the power of a1 [      1      64    2187   65536 1953125]

# %%
print("Addition of arrays:",a1+a2)
print(f"Addition of {a1} and {a2}: {a1+a2}")
# Out:
# Addition of arrays: [ 6  8 10 12 14]
# Addition of [5 6 7 8 9] and [1 2 3 4 5]: [ 6  8 10 12 14]

# %%
print("Sine: ",np.sin(a1))
print("Natuaral logarithm: ",np.log(a1))
print("Base-2 logarithm: ",np.log2(a1))
print("Exponential: ",np.exp(a1))
# Out:
# Sine:  [-0.95892427 -0.2794155   0.6569866   0.98935825  0.41211849]
# Natuaral logarithm:  [1.60943791 1.79175947 1.94591015 2.07944154 2.19722458]
# Base-2 logarithm:  [2.32192809 2.5849625  2.80735492 3.         3.169925  ]
# Exponential:  [ 148.4131591   403.42879349 1096.63315843 2980.95798704 8103.08392758]

# %% [markdown]
# **Part-02: Lab Task is to visualize the datasets or data using Matplotlib builtin function Graphs
# Generate Scatterplot
# Let's suppose we collected age (in years), height (in cm), and weight (in kilograms) information from few patients visitng a clinic.**

# %%
import matplotlib.pyplot as plt

# %%
people = ['Rithu', 'Neethu', 'Muskan', 'Pushpa']
age =[25, 25, 19, 31]
height =[145, 151, 165, 164]
weight=[45, 55, 65, 30]

# %% [markdown]
# **Scatter Plot**

# %%
plt.scatter(weight, height)
plt.title("Relationship between Weight and Height of patients")
plt.xlabel("Weight (in kgs)")
plt.ylabel("Height (in meters)")
plt.show()

# %% [markdown]
# **Bar Chart**

# %%
plt.bar(people, height)
plt.title("Height of patients")
plt.xlabel("People")
plt.ylabel("Height")
plt.show()

# %% [markdown]
# **Histogram**

# %%
plt.title("Histogram of patient's age",fontsize=16)
plt.hist(age,color='yellow', edgecolor = 'black', bins=5)
plt.xlabel('Age')
plt.ylabel('No. of patients')
plt.show()

# %% [markdown]
# Part-03: Access Data from various sources and formats

# %%
import pandas as pd

# %%
data1 = pd.read_table("/content/Java.txt")
data1
# Out:
#    Develop a java swing application to read age from the text box and checks whether the candidate is eligible for the vote or not. If he/she is eligible display " Congrats ",
# 0   Develop a java swing application to read a num...
# 1   Develop a java swing application to read a num...
# 2   Develop a java swing application for performin...
# 3   Develop a java program to create user defined ...
# 4   Write a java program to implement nested try a...
# 5   Write a java program to implement random acces...
# 6   Write java program to implement method overloa...
# 7   Write a java program to implement method overl...
# 8   Write java program to implement method overrid...
# 9   Write a java program to create two threads usi...
# 10  Write a java program to read two m*n matrices ...
# 11  Write a java program to implement multiple inh...

# %%
data2 = pd.read_excel("Online Retail.xlsx")
data2
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
data3 = pd.read_csv("/content/housing.csv")
data3
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...
